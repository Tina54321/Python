# %%
import json
import pandas as pd
with open('每日各站進出站人數/車站基本資料集.json', encoding='utf-8') as file:
    content:list[dict] = json.load(file)
info_df = pd.DataFrame(content)
info_df1 = info_df.reindex(columns=['stationCode', 'stationName', 'stationAddrTw'])
info_df1.columns = ['code', '站名', '地址']
info_df1.iloc[:20]
# Out:
#     code     站名                       地址
# 0   0900     基隆              基隆市仁愛區港西街5號
# 1   0910     三坑       基隆市仁愛區德厚里龍安街 206 號
# 2   0920     八堵       基隆市暖暖區八南里八堵路 142 號
# 3   0930     七堵         基隆市七堵區長興里東新街 2 號
# 4   0940     百福    基隆市七堵區堵南里明德三路 1 之 1 號
# 5   0950     五堵        新北市汐止區長安里長安路 17 號
# 6   0960     汐止         新北市汐止區信望里信義路 1 號
# 7   0970     汐科     新北市汐止區大同里大同路二段 182 號
# 8   0980     南港  臺北市南港區南港里南港路一段 313 號 B2
# 9   0990     松山         臺北市信義區松山路 11 號B1
# 10  1000     臺北        臺北市中正區黎明里北平西路 3 號
# 11  1001  臺北-環島                   臺北市中正區
# 12  1010     萬華       臺北市萬華區富福里康定路 382 號
# 13  1020     板橋     新北市板橋區新民里縣民大道二段 7 號
# 14  1030     浮洲      新北市板橋區僑中里僑中二街 156 號
# 15  1040     樹林       新北市樹林區樹北里鎮前街 112 號
# 16  1050    南樹林     新北市樹林區東山里中山路二段 230 號
# 17  1060     山佳        新北市樹林區中山里山佳街 28 號
# 18  1070     鶯歌       新北市鶯歌區東鶯里文化路 68-1號
# 19  1080     桃園         桃園市桃園區武陵里中正路 1 號
